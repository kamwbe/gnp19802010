# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# First I went to https://esa.un.org/unpd/wpp/Download/Standard/Population/ and downloaded 'Total Population both Sexes'.  I opened it in LibraOffice and saved it both as an .ods and a .cvs file to see which would be easier reading into a DataFrame.  I exported the file from LibraOffice as an html file and used the Pandas read_html to read it.

# %%
worldPop = pd.read_html('worldpop19502015.html')

# %%
# data read from and html file is loaded into a list of dataframes since there can be 
worldPopdf = worldPop[0]
worldPopdf.head(5)
# Out:
#       0          1                                     2      3   \
# 0  Index    Variant  Region, subregion, country or area *  Notes
# 1      1  Estimates                                 WORLD    NaN
# 2      2  Estimates                More developed regions      a
# 3      3  Estimates                Less developed regions      b
# 4      4  Estimates             Least developed countries      c
#
#              4          5          6          7          8          9   \
# 0  Country code       1950       1951       1952       1953       1954
# 1           900  2 536 275  2 583 817  2 630 584  2 677 230  2 724 302
# 2           901    814 865    824 213    834 074    844 264    854 632
# 3           902  1 721 410  1 759 604  1 796 510  1 832 967  1 869 671
# 4           941    195 259    199 052    202 905    206 885    211 045
#
#      ...             61         62         63         64         65  \
# 0    ...           2006       2007       2008       2009       2010
# 1    ...      6 623 848  6 706 419  6 789 771  6 873 741  6 958 169
# 2    ...      1 215 325  1 220 392  1 225 552  1 230 534  1 235 143
# 3    ...      5 408 523  5 486 027  5 564 219  5 643 207  5 723 027
# 4    ...        772 489    790 978    809 731    828 953    848 792
#
#           66         67         68         69         70
# 0       2011       2012       2013       2014       2015
# 1  7 043 009  7 128 177  7 213 426  7 298 453  7 383 009
# 2  1 239 298  1 243 055  1 246 520  1 249 864  1 253 207
# 3  5 803 711  5 885 122  5 966 906  6 048 590  6 129 802
# 4    869 298    890 423    912 094    934 192    956 631
#
# [5 rows x 71 columns]

# %%
# from the above dump we can see that the column names are part of the data.  First
# we need to extract those column names and reset the df to have those column names
new_columns = worldPopdf.iloc[0,:]
worldPopdf.columns = new_columns
worldPopdf.head(5)
# Out:
# 0  Index    Variant  Region, subregion, country or area *  Notes  \
# 0  Index    Variant  Region, subregion, country or area *  Notes
# 1      1  Estimates                                 WORLD    NaN
# 2      2  Estimates                More developed regions      a
# 3      3  Estimates                Less developed regions      b
# 4      4  Estimates             Least developed countries      c
#
# 0  Country code       1950       1951       1952       1953       1954  \
# 0  Country code       1950       1951       1952       1953       1954
# 1           900  2 536 275  2 583 817  2 630 584  2 677 230  2 724 302
# 2           901    814 865    824 213    834 074    844 264    854 632
# 3           902  1 721 410  1 759 604  1 796 510  1 832 967  1 869 671
# 4           941    195 259    199 052    202 905    206 885    211 045
#
# 0    ...           2006       2007       2008       2009       2010  \
# 0    ...           2006       2007       2008       2009       2010
# 1    ...      6 623 848  6 706 419  6 789 771  6 873 741  6 958 169
# 2    ...      1 215 325  1 220 392  1 225 552  1 230 534  1 235 143
# 3    ...      5 408 523  5 486 027  5 564 219  5 643 207  5 723 027
# 4    ...        772 489    790 978    809 731    828 953    848 792
#
# 0       2011       2012       2013       2014       2015
# 0       2011       2012       2013       2014       2015
# 1  7 043 009  7 128 177  7 213 426  7 298 453  7 383 009
# 2  1 239 298  1 243 055  1 246 520  1 249 864  1 253 207
# 3  5 803 711  5 885 122  5 966 906  6 048 590  6 129 802
# 4    869 298    890 423    912 094    934 192    956 631
#
# [5 rows x 71 columns]

# %%
# now we need to get rid of the first row which has the column names
# we do this by copying the df starting with row 2
worldPopdf = worldPopdf.iloc[1:] 
worldPopdf.head(3)
# Out:
# 0 Index    Variant Region, subregion, country or area * Notes Country code  \
# 1     1  Estimates                                WORLD   NaN          900
# 2     2  Estimates               More developed regions     a          901
# 3     3  Estimates               Less developed regions     b          902
#
# 0       1950       1951       1952       1953       1954    ...      \
# 1  2 536 275  2 583 817  2 630 584  2 677 230  2 724 302    ...
# 2    814 865    824 213    834 074    844 264    854 632    ...
# 3  1 721 410  1 759 604  1 796 510  1 832 967  1 869 671    ...
#
# 0       2006       2007       2008       2009       2010       2011  \
# 1  6 623 848  6 706 419  6 789 771  6 873 741  6 958 169  7 043 009
# 2  1 215 325  1 220 392  1 225 552  1 230 534  1 235 143  1 239 298
# 3  5 408 523  5 486 027  5 564 219  5 643 207  5 723 027  5 803 711
#
# 0       2012       2013       2014       2015
# 1  7 128 177  7 213 426  7 298 453  7 383 009
# 2  1 243 055  1 246 520  1 249 864  1 253 207
# 3  5 885 122  5 966 906  6 048 590  6 129 802
#
# [3 rows x 71 columns]

# %%
worldPopdf.drop('Variant', axis=1, inplace=True)
# Out:
# /home/marty/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
worldPopdf.drop('Index', axis=1, inplace=True)
worldPopdf.head(3)
# Out:
# /home/marty/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0 Region, subregion, country or area * Notes Country code       1950  \
# 1                                WORLD   NaN          900  2 536 275
# 2               More developed regions     a          901    814 865
# 3               Less developed regions     b          902  1 721 410
#
# 0       1951       1952       1953       1954       1955       1956  \
# 1  2 583 817  2 630 584  2 677 230  2 724 302  2 772 243  2 821 383
# 2    824 213    834 074    844 264    854 632    865 069    875 507
# 3  1 759 604  1 796 510  1 832 967  1 869 671  1 907 173  1 945 876
#
# 0    ...           2006       2007       2008       2009       2010  \
# 1    ...      6 623 848  6 706 419  6 789 771  6 873 741  6 958 169
# 2    ...      1 215 325  1 220 392  1 225 552  1 230 534  1 235 143
# 3    ...      5 408 523  5 486 027  5 564 219  5 643 207  5 723 027
#
# 0       2011       2012       2013       2014       2015
# 1  7 043 009  7 128 177  7 213 426  7 298 453  7 383 009
# 2  1 239 298  1 243 055  1 246 520  1 249 864  1 253 207
# 3  5 803 711  5 885 122  5 966 906  6 048 590  6 129 802
#
# [3 rows x 69 columns]

# %%
# ok now look at the numbers in the year columns.  Instead of having an int or a float the thousands of the
# number has spaces between them.  So the df treats them as separate.  We need to convert this into one
# floating point number.
worldPopdf.loc[1]['1950']
# Out:
# '2 536 275'

# %%
# pat1 will look for numbers up to 999 999 999 999.  So the first re finds the number with spaces
# in it and the second re removes the spaces.  Finally we return the number as a float.
pat1=r'(\d+\s?\d*\s?\d*\s?\d*)'
re1=re.compile(pat1)

# %%
def pop_modifier(x):
    num = re1.search(x).group()
    num2 = re.sub('\s', '', num, count=0, flags=0)
    return float(num2)
