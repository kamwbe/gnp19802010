# %%
import numpy as np
import pandas as pd

# %%
# first get the clean_worldPop19502015.csv that was created by population_cleaner.ipynb
allpops = pd.read_csv('clean_worldPop19502015.csv')
allpops.head(5)
# Out:
#                 Region, subregion, country or area *  Country code       1950  \
# 0                                              WORLD           900  2536275.0
# 1                             More developed regions           901   814865.0
# 2                             Less developed regions           902  1721410.0
# 3                          Least developed countries           941   195259.0
# 4  Less developed regions, excluding least develo...           934  1526151.0
#
#         1951       1952       1953       1954       1955       1956  \
# 0  2583817.0  2630584.0  2677230.0  2724302.0  2772243.0  2821383.0
# 1   824213.0   834074.0   844264.0   854632.0   865069.0   875507.0
# 2  1759604.0  1796510.0  1832967.0  1869671.0  1907173.0  1945876.0
# 3   199052.0   202905.0   206885.0   211045.0   215421.0   220033.0
# 4  1560552.0  1593605.0  1626082.0  1658626.0  1691752.0  1725843.0
#
#         1957    ...           2006       2007       2008       2009  \
# ...

# %%
allpops.columns
# Out:
# Index(['Region, subregion, country or area *', 'Country code', '1950', '1951',
#        '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960',
#        '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object')

# %%
# now extract Region..., Country code and 1980 columns for the 1980 population file
pop1980 = allpops[['Region, subregion, country or area *','Country code','1980']]
pop1980.head(5)
# Out:
#                 Region, subregion, country or area *  Country code       1980
# 0                                              WORLD           900  4458412.0
# 1                             More developed regions           901  1084244.0
# 2                             Less developed regions           902  3374167.0
# 3                          Least developed countries           941   393279.0
# 4  Less developed regions, excluding least develo...           934  2980888.0

# %%
pop1980.to_csv('pop1980.csv', line_terminator='\n', index=False, header=True)

# %%
# now extract Region..., Country code and 2010 columns for the 2010 population file
pop2010 = allpops[['Region, subregion, country or area *','Country code','2010']]
pop2010.head(5)
# Out:
#                 Region, subregion, country or area *  Country code       2010
# 0                                              WORLD           900  6958169.0
# 1                             More developed regions           901  1235143.0
# 2                             Less developed regions           902  5723027.0
# 3                          Least developed countries           941   848792.0
# 4  Less developed regions, excluding least develo...           934  4874235.0

# %%
pop2010.to_csv('pop2010.csv', line_terminator='\n', index=False, header=True)
